# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
data={
    'Temperature' : [20,22,25,28],
    'Ice Cream Sold' : [100,120,130,200]
}
df=pd.DataFrame(data)
X=df[['Temperature']]
y=df['Ice Cream Sold']
model=LinearRegression()
model.fit(X,y)
new_data = pd.DataFrame({'Temperature': [26]})
prediction = model.predict(new_data)

print("Prediction of ice cream sold:", prediction[0])
# Out:
# Prediction of ice cream sold: 163.67346938775512

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
data={
    'Temperature' : [20,22,25,28],
    'Ice Cream Sold' : [100,120,130,200]
}
df=pd.DataFrame(data)
X=df[['Temperature']]
y=df['Ice Cream Sold']
model=LinearRegression()
model.fit(X,y)
plt.scatter(X,y)
plt.plot(X,model.predict(X))
plt.xlabel("Temperature")
plt.ylabel("Ice Cream Sold")
plt.title("Linear Regression")

plt.show()
